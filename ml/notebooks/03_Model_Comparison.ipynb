# %% [markdown]
# # F1 Model Comparison & Ensemble Evaluation
# This notebook compares XGBoost, LightGBM, and the Stacking Ensemble meta-learner.

# %%
import joblib
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import RocCurveDisplay

# Load data and models
df = pd.read_parquet('../../data/processed/f1_features_full.parquet')
xgb = joblib.load('../inference/models/xgb_winner.pkl')
lgbm = joblib.load('../inference/models/lgbm_podium.pkl')

print("Success: Models loaded for comparison.")
